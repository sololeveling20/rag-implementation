# %% [markdown]
# <a href="https://colab.research.google.com/github/sololeveling20/rag-implementation/blob/main/RAG_Chatbot_LearnNex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1

# %%
# !pip install langchain_community langchainhub chromadb langchain-openai

# %% [markdown]
# Step 2

# %%
from google.colab import userdata
import os
os.environ['OPENAI_API_KEY'] = userdata.get('rag-project')

# %% [markdown]
# Step 3

# %%
import os
print("API key loaded:", os.environ.get("OPENAI_API_KEY") is not None)
# Out:
# API key loaded: True

# %% [markdown]
# Step 4

# %%
import os
print(os.environ.get("OPENAI_API_KEY")[:8])
# Out:
# sk-proj-

# %% [markdown]
# Step 5

# %%
from langchain_community.llms import HuggingFacePipeline
from transformers import pipeline

pipe = pipeline(
    "text-generation",
    model="google/flan-t5-small",
    max_new_tokens=128
)

llm = HuggingFacePipeline(pipeline=pipe)

print(llm.invoke("Say hello in one word"))
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/308M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ...

# %% [markdown]
# Step 6

# %%
from transformers import pipeline
from langchain_community.llms import HuggingFacePipeline

pipe = pipeline(
    task="text2text-generation",
    model="google/flan-t5-small",
    max_new_tokens=64
)

llm = HuggingFacePipeline(pipeline=pipe)

print(llm.invoke("Say hello in one word"))
# Out:
# Device set to use cpu
# hello in one word

# %% [markdown]
# Step 7

# %%
context = "Python is a programming language."
question = "What is Python?"

print(llm.invoke(f"Context: {context}\nQuestion: {question}\nAnswer:"))
# Out:
# programming language

# %% [markdown]
# Step 8

# %%
# !pip install -q pypdf
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.2/328.2 kB 19.6 MB/s eta 0:00:00

# %% [markdown]
# Step 9

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("/content/DF case study.pdf")
loader = PyPDFLoader('/content/DF Notes Unit 5.pdf')
documents = loader.load()

print(documents[0].metadata)
print("Total pages loaded:", len(documents))
print(documents[0].page_content[:300])
# Out:
# {'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2025-12-18T14:32:37+00:00', 'author': 'VIJAY JADHAV', 'moddate': '2025-12-18T14:32:37+00:00', 'source': '/content/DF Notes Unit 5.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1'}
# Total pages loaded: 5
# 1️⃣ Processing Crimes and Incident Scenes
# Definition:
# Processing a digital crime or incident scene involves identifying, documenting, preserving,
# and collecting electronic evidence in a manner that maintains its integrity and admissibility in
# court.
# Key Steps:
# 1. Identify the Scene:
# Determine

# %% [markdown]
# Step 10

# %%
# !pip install -q langchain-core

# %% [markdown]
# Step 11

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

chunks = text_splitter.split_documents(documents)

print(chunks[0].metadata)
print("Total chunks created:", len(chunks))
print(chunks[0].page_content[:300])
# Out:
# {'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2025-12-18T14:32:37+00:00', 'author': 'VIJAY JADHAV', 'moddate': '2025-12-18T14:32:37+00:00', 'source': '/content/DF Notes Unit 5.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1'}
# Total chunks created: 17
# 1️⃣ Processing Crimes and Incident Scenes
# Definition:
# Processing a digital crime or incident scene involves identifying, documenting, preserving,
# and collecting electronic evidence in a manner that maintains its integrity and admissibility in
# court.
# Key Steps:
# 1. Identify the Scene:
# Determine

# %% [markdown]
# Step 12

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma

# Create embedding model
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# Create Chroma vector store (in-memory)
vectorstore = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings
)

print("ChromaDB created with", vectorstore._collection.count(), "documents")
# Out:
# ChromaDB created with 45 documents

# %% [markdown]
# Step 13

# %%
retriever = vectorstore.as_retriever(search_kwargs={"k": 3})

query = "What is the case study about?"

docs = retriever.invoke(query)

print("Retrieved documents:\n")

for i, doc in enumerate(docs):
    print(f"--- Document {i+1} ---")
    print("Source:", doc.metadata.get("source"))
    print("Page:", doc.metadata.get("page"))
    print("Content preview:")
    print(doc.page_content[:300])
    print("\n")
# Out:
# Retrieved documents:
#
# --- Document 1 ---
# Source: /content/DF Notes Unit 5.pdf
# Page: 3
# Content preview:
# Importance:
#  Prevents alteration of original data.
#  Ensures integrity and admissibility in court.
#  Allows repeated analysis without risk of data loss.
#
#
# --- Document 2 ---
# Source: /content/DF Notes Unit 5.pdf
# Page: 0
# Content preview:
# systems.
# 5. Collect and Label Evidence:
# Label every device and media clearly. Follow evidence numbering and logging
# procedures.
# 6. Maintain Chain of Custody:
# Track who handled the evidence, when, and for what purpose. This ensures legal
# credibility.
#
# 2️⃣ Securing a Computer Incident or Crime
#
#
# --- Document 3 ---
# Source: /content/DF Notes Unit 5.pdf
# Page: 2
# Content preview:
#  Cross-check evidence with investigation goals.
#  Re-examine important findings for consistency.
#  Ensure all actions are reproducible and defensible in court.
# ...

# %% [markdown]
# Step 14

# %%
from transformers import pipeline
from langchain_community.llms import HuggingFacePipeline

pipe = pipeline(
    task="text2text-generation",
    model="google/flan-t5-small",
    max_new_tokens=128
)

llm = HuggingFacePipeline(pipeline=pipe)

print("LLM ready ✅")
# Out:
# Device set to use cpu
# LLM ready ✅

# %% [markdown]
# Step 15

# %%
query = input("Ask a question about the document: ")

docs = retriever.invoke(query)

context = ""
for doc in docs:
    source = doc.metadata.get("source", "Unknown")
    page = doc.metadata.get("page", "N/A")
    context += f"[Source: {source}, Page: {page}]\n{doc.page_content}\n\n"

prompt = f"""
Answer the question using ONLY the context below.
If the answer is not present, say:
"Not found in the provided documents."

Context:
{context}

Question:
{query}

Answer:
"""

answer = llm.invoke(prompt)

# Print final output
print("\nAnswer:")
print(answer)

print("\nSources:")
unique_sources = set(
    (doc.metadata['source'], doc.metadata['page'])
    for doc in docs
)

for src, page in unique_sources:
    print(f"- {src.split('/')[-1]} (Page {page})")
# Out:
# Ask a question about the document: What is Social Media
#
# Answer:
# Not found in the provided documents.
#
# Sources:
# - DF case study.pdf (Page 0)
# - DF case study.pdf (Page 5)
